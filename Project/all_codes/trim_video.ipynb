# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
import os

# %%
# folder where each ball video and frames are saved
folder = "./frames"
VIDEO_PATH = "../videos/t1.mp4"

if not os.path.exists(folder):
    os.makedirs(folder)

# %%
ballCounts = 0
for filename in os.listdir(folder):
    ballCounts += 1
ballCounts /= 2
print("Total balls folder: ",ballCounts)
ballCounts += 1

trimVideo = open("trim.txt", "r")
lines = trimVideo.read().split('\n')
# ignoring the last \n line (if any)
L = len(lines)
if(len(lines[L - 1]) == 0):
    lines.remove("")
    L -= 1
print (lines)
# Out:
# ('Total balls folder: ', 50)
# ['1 38 1 1 38 15', '1 38 28 1 38 38', '1 39 01 1 39 13', '1 39 28 1 39 50', '1 41 48 1 42 2', '1 42 26 1 42 42', '1 43 54 1 44 3', '1 44 32 1 44 45', '1 45 1 1 45 4', '1 45 18 1 45 27', '1 45 47 1 45 56', '1 46 13 1 46 30', '1 48 45 1 48 53', '1 49 38 1 49 46', '1 50 13 1 50 20', '1 50 49 1 51 9', '1 51 36 1 51 50', '1 52 15 1 52 27', '1 53 16 1 53 26', '1 53 56 1 54 6', '1 54 21 1 54 29', '1 54 44 1 55 4', '1 55 22 1 55 36', '1 55 55 1 56 2', '1 57 9 1 57 17', '1 57 53 1 58 9', '1 59 57 2 00 2', '2 00 29 2 00 37', '2 1 2 2 1 10', '2 1 38 2 1 53', '2 3 36 2 3 42', '2 3 59 2 4 8', '2 4 44 2 4 50', '2 5 3 2 5 9', '2 5 24 2 5 31', '2 5 49 2 5 57', '2 6 57 2 7 6', '2 7 32 2 7 40', '2 8 17 2 8 25', '2 8 53 2 9 7', '2 9 34 2 9 44', '2 10 11 2 10 27', '2 11 59 2 12 13', '2 12 35 2 12 43', '2 13 9 2 13 13', '2 13 42 2 13 51', '2 14 18 2 14 26', '2 14 52 2 14 58', '2 15 53 2 16 2', '2 16 30 2 16 40', '2 17 62 17 19', '2 17 41 2 17 51', '2 18 19 2 18 28', '2 18 56 2 19 11', '2 20 37 2 20 44', '2 21 31 2 21 38', '2 22 4 2 22 14', '2 22 36 2 22 43', '2 23 17 2 23 26', '2 24 14 2 24 22', '2 25 0 2 25 5', '2 25 35 2 25 40', '2 26 40 2 26 49', '2 27 15 2 27 33', '2 27 56 2 28 6', '2 28 36 2 28 44', '2 30 4 2 30 14', '2 30 41 2 30 49', '2 31 44 2 31 53', '2 32 16 2 32 27', '2 32 51 2 32 57', '2 33 24 2 33 30', '2 33 56 2 34 11', '2 34 35 2 34 43', '2 35 6 2 35 17']

# %%
def trim_and_save_video(line, ballCounts):
    h1, m1, s1, h2, m2, s2 = map(int, line.split(" "))
#     Converting Min:Sec to Sec
#     taking margin of 0.75 sec before starting time and after ending time
    start_time = h1 * 60 * 60 + m1 * 60 + s1 - 0.75
    end_time = h2 * 60 * 60 + m2 * 60 + s2 + 0.75
    os.makedirs(folder + "/" + ballCounts)
    ffmpeg_extract_subclip(VIDEO_PATH, start_time, end_time, targetname=folder + "/" + ballCounts + ".mp4")

# %%
for i in range(L):
    trim_and_save_video(lines[i], str(ballCounts))
    ballCounts += 1
    print("Trimmed ", i)
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 0)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 1)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 2)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 3)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 4)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 5)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 6)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 7)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 8)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 9)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 10)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 11)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 12)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 13)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 14)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 15)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 16)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 17)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 18)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 19)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 20)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 21)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 22)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 23)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 24)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 25)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 26)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 27)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 28)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 29)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 30)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 31)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 32)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 33)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 34)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 35)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 36)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 37)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 38)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 39)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 40)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 41)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 42)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 43)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 44)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 45)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 46)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 47)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 48)
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ('Trimmed ', 49)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-e50fb7d68fdb> in <module>()
#       1 for i in range(L):
# ----> 2     trim_and_save_video(lines[i], str(ballCounts))
#       3     ballCounts += 1
#       4     print("Trimmed ", i)
#
# <ipython-input-9-489102a20d5b> in trim_and_save_video(line, ballCounts)
#       1 def trim_and_save_video(line, ballCounts):
# ----> 2     h1, m1, s1, h2, m2, s2 = map(int, line.split(" "))
#       3 #     Converting Min:Sec to Sec
#       4 #     taking margin of 0.75 sec before starting time and after ending time
#       5     start_time = h1 * 60 * 60 + m1 * 60 + s1 - 0.75
#
# ValueError: need more than 5 values to unpack
